# %% [markdown]
# # 21. Comparing Best Results
# In this notebook, I will compare all best methods so far to get an overview of the best results we got so far. Up until this point, we compare our scores mainly to the balanced 'sample_500' set, but now we also get scores from different methods over all main categories or the whole dataset for example. Let's see how those compare.
#
# ## Preprocessing

# %%
import pandas as pd
from preprocessing import PreProcessor

pp = PreProcessor()

df_all = pd.read_csv('Structured_DataFrame.csv', index_col=0)
df_all['Item Description'] = df_all['Item Description'].apply(lambda d: pp.preprocess(str(d)))
df_all
# Out:
#                    Category  \
# 0          Services/Hacking
# 1          Services/Hacking
# 2          Services/Hacking
# 3          Services/Hacking
# 4          Services/Hacking
# ...                     ...
# 109585  Drugs/Opioids/Opium
# 109586    Weapons/Fireworks
# 109587  Drugs/Opioids/Opium
# 109588  Drugs/Opioids/Opium
# 109589  Drugs/Opioids/Opium
#
#                                          Item Description  category_id
# 0       month huluplu gift code month huluplu code wor...            0
# 1       pay tv sky uk sky germani hd tv much cccam ser...            0
# 2       offici account creator extrem tag submiss fix ...            0
# 3       vpn tor sock tutori setup vpn tor sock super s...            0
# 4       facebook hack guid guid teach hack facebook ac...            0
# ...                                                   ...          ...
# 109585  gr purifi opium list gramm redefin opium pefec...           95
# 109586  ship ticket order ship one gun bought must bou...           99
# 109587  gram white afghani heroin full escrow gram whi...           95
# 109588  gram white afghani heroin full escrow gram whi...           95
# 109589  heroin stamp bag pc bundl heroin stamp bag pc ...           95
#
# [109563 rows x 3 columns]

# %%
df_main = pd.read_csv('Structured_DataFrame_Main_Categories.csv', index_col=0)
df_main['Item Description'] = df_main['Item Description'].apply(lambda d: pp.preprocess(str(d)))
df_main
# Out:
#         Category                                   Item Description  \
# 0       Services  month huluplu gift code month huluplu code wor...
# 1       Services  pay tv sky uk sky germani hd tv much cccam ser...
# 2       Services  offici account creator extrem tag submiss fix ...
# 3       Services  vpn tor sock tutori setup vpn tor sock super s...
# 4       Services  facebook hack guid guid teach hack facebook ac...
# ...          ...                                                ...
# 109585     Drugs  gr purifi opium list gramm redefin opium pefec...
# 109586   Weapons  ship ticket order ship one gun bought must bou...
# 109587     Drugs  gram white afghani heroin full escrow gram whi...
# 109588     Drugs  gram white afghani heroin full escrow gram whi...
# 109589     Drugs  heroin stamp bag pc bundl heroin stamp bag pc ...
#
#         category_id
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 109585            1
# 109586           11
# 109587            1
# 109588            1
# 109589            1
#
# [109563 rows x 3 columns]

# %%
df_balanced = pd.read_csv('Structured_DataFrame_Sample_500.csv', index_col=0)
df_balanced['Item Description'] = df_balanced['Item Description'].apply(lambda d: pp.preprocess(str(d)))
df_balanced
# Out:
#                    Category  \
# 40127  Counterfeits/Watches
# 40126  Counterfeits/Watches
# 40125  Counterfeits/Watches
# 40130  Counterfeits/Watches
# 40129  Counterfeits/Watches
# ...                     ...
# 15401        Services/Money
# 15402        Services/Money
# 15403        Services/Money
# 15404        Services/Money
# 15391        Services/Money
#
#                                         Item Description  category_id
# 40127  emporio armani ar shell case ceram bracelet re...            0
# 40126  cartiertank ladi brand cartier seri tank gende...            0
# 40125  patek philipp watch box patek philipp watch bo...            0
# 40130  breitl navitim cosmonaut replica watch inform ...            0
# 40129  emporio armani men ar dial color gari watch re...            0
# ...                                                  ...          ...
# 15401  canada cc get card number cvv expiri date name...           29
# 15402  uk debit card take chanc buy uk visa debit car...           29
# 15403  itali card detail high valid fresh itali card ...           29
# 15404  centurionblack cc get us centurion cc card num...           29
# 15391  buy coin vanilla reload send moneypak code zip...           29
#
# [15000 rows x 3 columns]

# %% [markdown]
# ## Vectorizing

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2))

features_all = tfidf.fit_transform(df_all['Item Description'])
labels_all = df_all.Category

features_all
# Out:
# <109563x102238 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3414110 stored elements in Compressed Sparse Row format>

# %%
features_main = tfidf.fit_transform(df_main['Item Description'])
labels_main = df_main.Category

features_main
# Out:
# <109563x102238 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3414110 stored elements in Compressed Sparse Row format>

# %%
features_balanced = tfidf.fit_transform(df_balanced['Item Description'])
labels_balanced = df_balanced.Category

features_balanced
# Out:
# <15000x16833 sparse matrix of type '<class 'numpy.float64'>'
# 	with 390081 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Splitting

# %%
from sklearn.model_selection import train_test_split

X_train_all, X_test_all, y_train_all, y_test_all, indices_train_all, indices_test_all = train_test_split(features_all, labels_all, df_all.index, test_size=0.33, random_state=0)
X_train_main, X_test_main, y_train_main, y_test_main, indices_train_main, indices_test_main = train_test_split(features_main, labels_main, df_main.index, test_size=0.33, random_state=0)
X_train_balanced, X_test_balanced, y_train_balanced, y_test_balanced, indices_train_balanced, indices_test_balanced = train_test_split(features_balanced, labels_balanced, df_balanced.index, test_size=0.33, random_state=0)

print(X_train_all.shape, X_test_all.shape)
print(X_train_main.shape, X_test_main.shape)
print(X_train_balanced.shape, X_test_balanced.shape)
# Out:
# (73407, 102238) (36156, 102238)
# (73407, 102238) (36156, 102238)
# (10050, 16833) (4950, 16833)

# %% [markdown]
# ## Training

# %%
from sklearn.svm import LinearSVC

model_all = LinearSVC()
model_main = LinearSVC()
model_balanced = LinearSVC()

model_all.fit(X_train_all, y_train_all)
model_main.fit(X_train_main, y_train_main)
model_balanced.fit(X_train_balanced, y_train_balanced)

y_pred_all = model_all.predict(X_test_all)
y_pred_main = model_main.predict(X_test_main)
y_pred_balanced = model_balanced.predict(X_test_balanced)

# %% [markdown]
# ## Results

# %%
from sklearn import metrics

print("Accuracy: ", metrics.accuracy_score(y_test_all, y_pred_all))
print()
print(metrics.classification_report(y_test_all, y_pred_all))
# Out:
# Accuracy:  0.893046797212081
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#                                                  precision    recall  f1-score   support
#
#                                       Chemicals       0.88      0.71      0.79        31
#                        Counterfeits/Accessories       0.92      0.73      0.81        75
#                           Counterfeits/Clothing       0.90      0.91      0.90       132
#                        Counterfeits/Electronics       0.67      0.53      0.59        15
#                              Counterfeits/Money       0.92      0.89      0.90       123
#                            Counterfeits/Watches       0.98      0.99      0.99       360
#                                   Data/Accounts       0.78      0.79      0.78       378
#                                    Data/Pirated       0.84      0.81      0.82       178
#                                   Data/Software       0.74      0.75      0.74       119
#                        Drugs/Psychedelics/Other       0.83      0.82      0.83        90
#                       Drugs/Psychedelics/Others       0.70      0.56      0.62        34
#                       Drugs/Psychedelics/Salvia       0.80      1.00      0.89         8
#                       Drugs/Psychedelics/Spores       0.80      0.80      0.80        30
#                                       Drugs/RCs       0.92      0.91      0.91       720
#                                  Drugs/Steroids       0.96      0.96      0.96       941
#                        Drugs/Stimulants/Cocaine       0.98      0.97      0.98      1972
#                     Drugs/Stimulants/Mephedrone       0.88      0.78      0.82         9
#                           Drugs/Stimulants/Meth       0.96      0.95      0.95       798
#                   Drugs/Stimulants/Prescription       0.81      0.82      0.82       635
#                          Drugs/Stimulants/Speed       0.96      0.94      0.95       812
#                               Drugs/Weight loss       0.74      0.68      0.70        74
#                                     Electronics       0.73      0.81      0.77       192
#                                       Forgeries       1.00      0.75      0.86         4
#                                 Forgeries/Other       0.95      0.70      0.81        27
#                    Forgeries/Physical documents       0.88      0.89      0.88       189
#                          Forgeries/Scans/Photos       0.83      0.83      0.83       103
#                         Info/eBooks/Aliens/UFOs       0.00      0.00      0.00         5
#                           Info/eBooks/Anonymity       0.09      0.06      0.07        63
#                            Info/eBooks/Doomsday       0.38      0.43      0.40        14
#                               Info/eBooks/Drugs       0.48      0.50      0.49        96
#                             Info/eBooks/Economy       0.09      0.06      0.07        18
#                                  Info/eBooks/IT       0.42      0.38      0.40        48
#                        Info/eBooks/Making money       0.38      0.42      0.40       110
#                               Info/eBooks/Other       0.31      0.24      0.27       244
#                          Info/eBooks/Philosophy       0.00      0.00      0.00         4
#                            Info/eBooks/Politics       0.00      0.00      0.00        11
#                          Info/eBooks/Psychology       0.33      0.08      0.13        12
#                   Info/eBooks/Relationships/Sex       0.48      0.50      0.49        48
#                             Info/eBooks/Science       0.31      0.25      0.28        52
#                              Information/Guides       0.39      0.37      0.38       323
#                              Information/eBooks       0.40      0.42      0.41       319
#                                         Jewelry       0.84      0.84      0.84       129
#                                           Other       0.48      0.45      0.46       474
#                            Services/Advertising       0.84      0.82      0.83        44
#                                Services/Hacking       0.59      0.58      0.58       152
#                                  Services/Money       0.63      0.73      0.68       450
#                                  Services/Other       0.40      0.32      0.36       154
#                                 Services/Travel       0.63      0.89      0.74        37
#                           Tobacco/Paraphernalia       1.00      0.29      0.44         7
#                                  Tobacco/Smoked       0.98      0.93      0.95       127
#                              Weapons/Ammunition       0.95      0.98      0.96        41
#                               Weapons/Fireworks       0.17      0.20      0.18         5
#                         Weapons/Lethal firearms       0.90      0.81      0.85       120
#                                   Weapons/Melee       0.81      0.85      0.83        26
#                     Weapons/Non-lethal firearms       0.71      0.80      0.75        15
#
#                                       micro avg       0.89      0.89      0.89     36156
#                                       macro avg       0.75      0.72      0.73     36156
#                                    weighted avg       0.89      0.89      0.89     36156

# %%
print("Accuracy: ", metrics.accuracy_score(y_test_main, y_pred_main))
print()
print(metrics.classification_report(y_test_main, y_pred_main))
# Out:
# Accuracy:  0.9539495519415865
#
#                     precision    recall  f1-score   support
#
#          Chemicals       0.95      0.68      0.79        31
#       Counterfeits       0.97      0.93      0.95       705
#               Data       0.86      0.80      0.83       675
# Drug paraphernalia       0.87      0.85      0.86       275
#              Drugs       0.98      1.00      0.99     30807
#        Electronics       0.78      0.78      0.78       192
#          Forgeries       0.94      0.91      0.92       323
#               Info       0.61      0.65      0.63       725
#        Information       0.47      0.40      0.43       642
#            Jewelry       0.88      0.84      0.86       129
#              Other       0.67      0.31      0.43       474
#           Services       0.69      0.71      0.70       837
#            Tobacco       0.99      0.90      0.94       134
#            Weapons       0.94      0.86      0.90       207
#
#          micro avg       0.95      0.95      0.95     36156
#          macro avg       0.83      0.76      0.79     36156
#       weighted avg       0.95      0.95      0.95     36156

# %%
print("Accuracy: ", metrics.accuracy_score(y_test_balanced, y_pred_balanced))
print()
print(metrics.classification_report(y_test_balanced, y_pred_balanced))
# Out:
# Accuracy:  0.9222222222222223
#
#                                precision    recall  f1-score   support
#
#          Counterfeits/Watches       1.00      0.99      1.00       162
#                 Data/Accounts       0.90      0.90      0.90       147
#                  Data/Pirated       0.95      0.92      0.94       157
#                  Drugs/Benzos       0.84      0.87      0.86       166
#   Drugs/Cannabis/Concentrates       0.95      0.94      0.95       172
#        Drugs/Cannabis/Edibles       0.98      0.98      0.98       162
#           Drugs/Cannabis/Hash       0.91      0.92      0.92       153
#          Drugs/Cannabis/Seeds       0.97      0.95      0.96       149
#     Drugs/Cannabis/Synthetics       0.95      0.96      0.96       170
#           Drugs/Cannabis/Weed       0.90      0.93      0.91       174
#  Drugs/Dissociatives/Ketamine       0.97      1.00      0.98       159
#            Drugs/Ecstasy/MDMA       0.99      0.92      0.95       182
#                 Drugs/Opioids       0.80      0.65      0.72       162
#        Drugs/Opioids/Fentanyl       0.94      0.96      0.95       165
#          Drugs/Opioids/Heroin       0.87      0.94      0.90       176
#       Drugs/Opioids/Oxycodone       0.89      0.91      0.90       170
#            Drugs/Prescription       0.74      0.63      0.68       168
#        Drugs/Psychedelics/DMT       0.93      0.97      0.95       159
#        Drugs/Psychedelics/LSD       0.99      0.98      0.99       175
#  Drugs/Psychedelics/Mushrooms       1.00      0.99      1.00       174
#         Drugs/Psychedelics/NB       0.99      0.99      0.99       164
#                     Drugs/RCs       0.92      0.92      0.92       165
#                Drugs/Steroids       0.96      0.98      0.97       181
#      Drugs/Stimulants/Cocaine       0.98      0.96      0.97       166
#         Drugs/Stimulants/Meth       0.96      0.98      0.97       161
# Drugs/Stimulants/Prescription       0.79      0.84      0.81       171
#        Drugs/Stimulants/Speed       0.98      0.94      0.96       171
#                   Electronics       0.88      0.90      0.89       160
#  Forgeries/Physical documents       0.89      0.93      0.91       166
#                Services/Money       0.83      0.88      0.86       143
#
#                     micro avg       0.92      0.92      0.92      4950
#                     macro avg       0.92      0.92      0.92      4950
#                  weighted avg       0.92      0.92      0.92      4950

# %% [markdown]
# ## Conclusion
# The best trained model we have so far is LinearSVC with TF-IDF vectorization. The scores for this pipeline are displayed above.
#
# The Multi-Layer Perceptron (notebook 19.1) scored 90,8% on the balanced set, compared to 92,2% for LinearSVC.
#
# The Multi-Layer Perceptron (notebook 19.2) scored 87,4% on the entire set, compared to 89,3% for LinearSVC.
#
# The Multi-Layer Perceptron (notebook 19.3) scored 94,8% on the main categories, compared to 95,4% for LinearSVC.
#
# We can conclude that the MLP performs pretty good, but it still can't match the LinearSVC model.
