# %% [markdown]
# # 19. Multi-Layer Perceptron (MLP) - Part 1
# Since I couldn't get CNN to work in the last notebook, I decided to try out another NN. This time one that was present already in the SKLearn library; MLP. https://www.kaggle.com/ahmethamzaemra/mlpclassifier-example
#
# ## Preprocessing

# %%
import pandas as pd
from preprocessing import PreProcessor

pp = PreProcessor()

df = pd.read_csv('Structured_DataFrame_Sample_500.csv', index_col=0)
df['Item Description'] = df['Item Description'].apply(lambda d: pp.preprocess(str(d)))
df
# Out:
#                    Category  \
# 40127  Counterfeits/Watches
# 40126  Counterfeits/Watches
# 40125  Counterfeits/Watches
# 40130  Counterfeits/Watches
# 40129  Counterfeits/Watches
# ...                     ...
# 15401        Services/Money
# 15402        Services/Money
# 15403        Services/Money
# 15404        Services/Money
# 15391        Services/Money
#
#                                         Item Description  category_id
# 40127  emporio armani ar shell case ceram bracelet re...            0
# 40126  cartiertank ladi brand cartier seri tank gende...            0
# 40125  patek philipp watch box patek philipp watch bo...            0
# 40130  breitl navitim cosmonaut replica watch inform ...            0
# 40129  emporio armani men ar dial color gari watch re...            0
# ...                                                  ...          ...
# 15401  canada cc get card number cvv expiri date name...           29
# 15402  uk debit card take chanc buy uk visa debit car...           29
# 15403  itali card detail high valid fresh itali card ...           29
# 15404  centurionblack cc get us centurion cc card num...           29
# 15391  buy coin vanilla reload send moneypak code zip...           29
#
# [15000 rows x 3 columns]

# %% [markdown]
# ## Vectorizing

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2))
features = tfidf.fit_transform(df['Item Description'])
labels = df.Category

features
# Out:
# <15000x16833 sparse matrix of type '<class 'numpy.float64'>'
# 	with 390081 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Splitting

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, df.index, test_size=0.33, random_state=0)

X_train
# Out:
# <10050x16833 sparse matrix of type '<class 'numpy.float64'>'
# 	with 261715 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Creating the model

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

clf = MLPClassifier(hidden_layer_sizes=(100,100,100), max_iter=500, learning_rate='constant', 
                    learning_rate_init=0.00001, alpha=0.001, solver='adam', verbose=1, 
                    random_state=21, tol=0.000001)
clf
# Out:
# MLPClassifier(activation='relu', alpha=0.001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 100, 100), learning_rate='constant',
#        learning_rate_init=1e-05, max_iter=500, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=21, shuffle=True, solver='adam', tol=1e-06,
#        validation_fraction=0.1, verbose=1, warm_start=False)

# %% [markdown]
# ## Training the model

# %%
clf.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 3.42113749
# Iteration 2, loss = 3.41865994
# Iteration 3, loss = 3.41621672
# Iteration 4, loss = 3.41375455
# Iteration 5, loss = 3.41120135
# Iteration 6, loss = 3.40855421
# Iteration 7, loss = 3.40579565
# Iteration 8, loss = 3.40287692
# Iteration 9, loss = 3.39983792
# Iteration 461, loss = 0.05205274
# Iteration 462, loss = 0.05176476
# Iteration 463, loss = 0.05145513
# Iteration 464, loss = 0.05117440
# Iteration 465, loss = 0.05091267
# Iteration 466, loss = 0.05061241
# Iteration 467, loss = 0.05033832
# Iteration 468, loss = 0.05005814
# Iteration 469, loss = 0.04978537
# Iteration 470, loss = 0.04951071
# Iteration 471, loss = 0.04923583
# Iteration 472, loss = 0.04896341
# Iteration 473, loss = 0.04871588
# Iteration 474, loss = 0.04844408
# Iteration 475, loss = 0.04816035
# Iteration 476, loss = 0.04793537
# Iteration 477, loss = 0.04767286
# Iteration 478, loss = 0.04741100
# Iteration 479, loss = 0.04715190
# Iteration 480, loss = 0.04691444
# Iteration 481, loss = 0.04665647
# Iteration 482, loss = 0.04641130
# Iteration 483, loss = 0.04618615
# Iteration 484, loss = 0.04594325
# Iteration 485, loss = 0.04570299
# Iteration 486, loss = 0.04546488
# Iteration 487, loss = 0.04523858
# Iteration 488, loss = 0.04500547
# Iteration 489, loss = 0.04476398
# Iteration 490, loss = 0.04453368
# Iteration 491, loss = 0.04432109
# Iteration 492, loss = 0.04408816
# Iteration 493, loss = 0.04387071
# Iteration 494, loss = 0.04365280
# Iteration 495, loss = 0.04342588
# Iteration 496, loss = 0.04322260
# Iteration 497, loss = 0.04299281
# Iteration 498, loss = 0.04279436
# Iteration 499, loss = 0.04257504
# Iteration 500, loss = 0.04237207
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPClassifier(activation='relu', alpha=0.001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 100, 100), learning_rate='constant',
#        learning_rate_init=1e-05, max_iter=500, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=21, shuffle=True, solver='adam', tol=1e-06,
#        validation_fraction=0.1, verbose=1, warm_start=False)

# %% [markdown]
# ## Validating the model

# %%
y_pred = clf.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.908080808080808

# %% [markdown]
# ## Save the model

# %%
import pickle

filename = 'MLP_500_Model.sav'
pickle.dump(clf, open(filename, 'wb'))

# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, y_test)
print(result)
# Out:
# 0.908080808080808

# %% [markdown]
# ## Conclusion
# The model has a pretty good accuracy score. Just a few percent lower than linear svc without a neural network. The learning rate concerns me though. The loss keeps declining slower and slower. This probably means the model is  overfitting. I tried to solve this by decreasing the tolerence so the model would stop training sooner. This did not really helpt though. I should probably adjust the value or the number of the weights. The most commonly used is to adjust the value of the weights by altering the penalty (alpha in this case). This is exactly what I tried. The result was that the model showed a decrease on a different number than zero. Aka; it evened out around 0.2 instead of 0.00. This is a good sign. In theory, the model should be more generalized now.
#
# https://machinelearningmastery.com/introduction-to-regularization-to-reduce-overfitting-and-improve-generalization-error/
# https://scikit-learn.org/stable/auto_examples/neural_networks/plot_mlp_alpha.html
#
# When I tried increasing the penalty though, the higher the training loss ended on, the weaker the model performed. I don't know why this is.
#
# In notebook 21 I will compare this score to other models.
