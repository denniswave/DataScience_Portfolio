# %% [markdown]
# # 7. ML Comparisons - Part 1
# To be able to determine which algorithm works best for our data, TNO would like to see a comparison of scores for several Machine Learning methods. In this notebook, multiple models will be trained with the same preprocessing method (and therefore the same dataset). All scores like recall and precision will be measured.

# %%
import pandas as pd
from io import StringIO
from sklearn.feature_extraction.text import TfidfVectorizer
from preprocessing import PreProcessor

pp = PreProcessor()

data = pd.read_csv('darkweb/data/agora.csv')

categories = data[' Category']
categories_main = data[' Category'].apply(lambda x: x.split('/')[0])
descriptions = data[' Item'] + " " + data[' Item Description']
descriptions_preprocessed = descriptions.apply(lambda d: pp.preprocess(str(d)))

# %% [markdown]
# ## Different dataframes
# Here, we create two different dataframes to be able to distinguish between main- and sub-categories.

# %%
# Sub
df = pd.DataFrame({'Category': categories, 'Item Description': descriptions_preprocessed})
df = df[pd.notnull(df['Item Description'])] # no empty descriptions
df = df[df.groupby('Category')['Category'].transform(len) > 1] # only categories that appear more than once

df['category_id'] = df['Category'].factorize()[0]
category_id_df = df[['Category', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'Category']].values)

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2))
features = tfidf.fit_transform(df['Item Description'])
labels = df.category_id

# Main
df_main = pd.DataFrame({'Category': categories_main, 'Item Description': descriptions_preprocessed})
df_main = df_main[pd.notnull(df_main['Item Description'])] # no empty descriptions
df_main = df_main[df_main.groupby('Category')['Category'].transform(len) > 1] # only categories that appear more than once

df_main['category_id'] = df_main['Category'].factorize()[0]
category_id_df_main = df_main[['Category', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id_main = dict(category_id_df_main.values)
id_to_category_main = dict(category_id_df_main[['category_id', 'Category']].values)

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2))
features_main = tfidf.fit_transform(df_main['Item Description'])
labels_main = df_main.category_id

df_main.head()
# Out:
#    Category                                   Item Description  category_id
# 0  Services  month huluplu gift code month huluplu code wor...            0
# 1  Services  pay tv sky uk sky germani hd tv much cccam ser...            0
# 2  Services  offici account creator extrem tag submiss fix ...            0
# 3  Services  vpn tor sock tutori setup vpn tor sock super s...            0
# 4  Services  facebook hack guid guid teach hack facebook ac...            0

# %% [markdown]
# ## Training
# After preprocessing, we train all models and predict with our test data. Note: a few weeks later, some parameters were changed. For example: random forest max_depth was increased from the standard 3 to 108 (1 for each category). This improved performance of that model drastically, but it still was not better than for example Linear SVC.

# %%
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split

main = False

if main:
    X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features_main, labels_main, df_main.index, test_size=0.33, random_state=0)
else:
    X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, df.index, test_size=0.33, random_state=0)
    
linearSVCModel = LinearSVC()
randomForestClassifierModel = RandomForestClassifier(n_estimators=200, max_depth=108, random_state=0)
multinomialNBModel = MultinomialNB()
logisticRegressionModel = LogisticRegression(random_state=0)
SGDClassifierModel = SGDClassifier(loss='hinge', penalty='l2', alpha=1e-5, max_iter=1000, tol=1e-3, class_weight='balanced')

linearSVCModel.fit(X_train, y_train)
randomForestClassifierModel.fit(X_train, y_train)
multinomialNBModel.fit(X_train, y_train)
logisticRegressionModel.fit(X_train, y_train)
SGDClassifierModel.fit(X_train, y_train)

y_predLinearSVC = linearSVCModel.predict(X_test)
y_predRandomForestClassifier = randomForestClassifierModel.predict(X_test)
y_predMultinomialNB = multinomialNBModel.predict(X_test)
y_predLogisticRegression = logisticRegressionModel.predict(X_test)
y_predSGDClassifier = SGDClassifierModel.predict(X_test)
# Out:
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %% [markdown]
# ## Confusion matrices and scores
# For insights into the classification process, we visualize the different models by showing their predictions into a confusion matrix. First, we create a functions that plots a confusion matrix. Then we plot al matrices and show scores of the models.

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn import metrics

def plot_confusion_matrix(modelName, modelPrediction):
    conf_mat = confusion_matrix(y_test, modelPrediction)
    fig, ax = plt.subplots(figsize=(75,25))
    sns.heatmap(conf_mat, annot=True, fmt='d', robust=True,
                xticklabels=category_id_df.Category.values, yticklabels=category_id_df.Category.values)

    plt.title(modelName + " Confusion Matrix")
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.savefig('Confusion Matrix - ' + modelName + '.png', bbox_inches='tight')
    plt.show()

# %% [markdown]
# ### Linear SVC

# %%
plot_confusion_matrix('Linear SVC', y_predLinearSVC)

# %%
print(metrics.classification_report(y_test, y_predLinearSVC, target_names=df['Category'].unique()))
# Out:
#                                                  precision    recall  f1-score   support
#
#                                Services/Hacking       0.54      0.51      0.52       146
#                                  Services/Other       0.44      0.38      0.41       168
#                                       Drugs/RCs       0.90      0.91      0.90       703
#                    Forgeries/Physical documents       0.84      0.89      0.87       197
#                                  Tobacco/Smoked       1.00      0.93      0.96       131
#                                  Services/Money       0.59      0.77      0.67       448
#                              Counterfeits/Money       0.89      0.86      0.87       129
#                                   Data/Software       0.72      0.69      0.70       110
#                                   Data/Accounts       0.79      0.79      0.79       400
#                           Counterfeits/Clothing       0.92      0.91      0.91       134
#                              Information/eBooks       0.35      0.40      0.37       298
#                                     Electronics       0.73      0.82      0.77       200
#                        Drug paraphernalia/Pipes       0.80      0.68      0.73        69
#                               Drugs/Weight loss       0.78      0.65      0.71        83
#                                    Data/Pirated       0.86      0.84      0.85       182
#                                  Drugs/Steroids       0.96      0.97      0.96       942
#                              Drugs/Prescription       0.82      0.81      0.82      1844
#                              Information/Guides       0.38      0.36      0.37       320
UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### Random Forest Classifier

# %%
plot_confusion_matrix('Random Forest Classifier', y_predRandomForestClassifier)

# %%
print(metrics.classification_report(y_test, y_predRandomForestClassifier, target_names=df['Category'].unique()))
# Out:
#                                                  precision    recall  f1-score   support
#
#                                Services/Hacking       0.80      0.16      0.27       146
#                                  Services/Other       0.77      0.12      0.21       168
#                                       Drugs/RCs       0.93      0.81      0.87       703
#                    Forgeries/Physical documents       0.90      0.72      0.80       197
#                                  Tobacco/Smoked       1.00      0.86      0.93       131
#                                  Services/Money       0.65      0.62      0.64       448
#                              Counterfeits/Money       0.91      0.58      0.71       129
#                                   Data/Software       0.94      0.15      0.27       110
#                                   Data/Accounts       0.77      0.75      0.76       400
#                           Counterfeits/Clothing       0.91      0.71      0.80       134
#                              Information/eBooks       0.63      0.11      0.18       298
#                                     Electronics       0.95      0.21      0.34       200
#                        Drug paraphernalia/Pipes       0.95      0.26      0.41        69
#                               Drugs/Weight loss       0.89      0.30      0.45        83
#                                    Data/Pirated       0.91      0.64      0.75       182
#                                  Drugs/Steroids       0.94      0.90      0.92       942
#                              Drugs/Prescription       0.69      0.81      0.74      1844
#                              Information/Guides       0.42      0.13      0.20       320
#                          Forgeries/Scans/Photos       0.95      0.63      0.76       109
#                                           Other       0.74      0.09      0.17       477
#                                         Jewelry       0.80      0.59      0.68       129
#                                     Drugs/Other       0.88      0.43      0.58       274
#                        Counterfeits/Accessories       0.77      0.42      0.55        71
#                            Counterfeits/Watches       0.96      0.97      0.97       352
#                             Drugs/Cannabis/Weed       0.63      0.99      0.77      6898
#                                    Drugs/Benzos       0.92      0.92      0.92      1750
#                       Drugs/Cannabis/Shake/trim       0.92      0.55      0.69        44
#                       Drugs/Cannabis/Synthetics       0.98      0.67      0.79       234
#                     Drugs/Cannabis/Concentrates       0.95      0.88      0.92      1429
#                            Drugs/Cannabis/Seeds       0.97      0.58      0.72       173
#                             Drugs/Cannabis/Hash       0.95      0.89      0.92      1058
#                         Drugs/Dissociatives/MXE       0.95      0.98      0.97       143
#                    Drugs/Dissociatives/Ketamine       0.99      0.94      0.96       339
#                          Drugs/Cannabis/Edibles       0.95      0.72      0.82       360
#                             Drugs/Ecstasy/Pills       0.96      0.97      0.97      2497
#                             Drugs/Ecstasy/Other       0.94      0.78      0.85       336
#                           Drugs/Stimulants/Meth       0.96      0.95      0.96       828
#                          Drugs/Psychedelics/LSD       0.97      0.98      0.98      1271
#                          Drugs/Stimulants/Speed       0.94      0.92      0.93       809
#                         Drugs/Dissociatives/GHB       0.99      0.90      0.94        73
#                        Drugs/Stimulants/Cocaine       0.98      0.94      0.96      2021
#                           Drugs/Psychedelics/NB       0.99      0.94      0.96       315
#                    Drugs/Psychedelics/Mushrooms       0.90      0.93      0.92       410
#                              Drugs/Ecstasy/MDMA       0.94      0.95      0.95      2071
#                          Drugs/Psychedelics/DMT       0.94      0.89      0.91       259
#                         Weapons/Lethal firearms       0.97      0.23      0.38       128
#                   Drugs/Stimulants/Prescription       0.82      0.77      0.79       618
#                               Drugs/Ecstasy/MDA       0.95      0.88      0.91       121
#                       Drugs/Psychedelics/Others       0.77      0.30      0.43        33
#                    Drugs/Psychedelics/Mescaline       0.86      0.22      0.35        27
#                           Drugs/Psychedelics/2C       0.95      0.86      0.90       318
#                       Drug paraphernalia/Scales       1.00      0.25      0.40        12
#  Drug paraphernalia/Injecting equipment/Filters       0.00      0.00      0.00         2
#  Drug paraphernalia/Injecting equipment/Needles       1.00      0.20      0.33         5
#                         Drugs/Dissociatives/PCP       0.00      0.00      0.00         1
#
#                                        accuracy                           0.82     36164
#                                       macro avg       0.78      0.48      0.55     36164
#                                    weighted avg       0.84      0.82      0.80     36164
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### Multinomial Naive Bais

# %%
plot_confusion_matrix('Multinomial Naive Bais', y_predMultinomialNB)

# %%
print(metrics.classification_report(y_test, y_predMultinomialNB, target_names=df['Category'].unique()))
# Out:
#                                                  precision    recall  f1-score   support
#
#                                Services/Hacking       1.00      0.10      0.17       146
#                                  Services/Other       1.00      0.07      0.12       168
#                                       Drugs/RCs       0.56      0.75      0.64       703
#                    Forgeries/Physical documents       0.91      0.57      0.70       197
#                                  Tobacco/Smoked       1.00      0.77      0.87       131
#                                  Services/Money       0.49      0.58      0.53       448
#                              Counterfeits/Money       1.00      0.15      0.26       129
#                                   Data/Software       0.96      0.24      0.38       110
#                                   Data/Accounts       0.79      0.71      0.75       400
#                           Counterfeits/Clothing       0.98      0.61      0.75       134
#                              Information/eBooks       0.41      0.09      0.15       298
#                                     Electronics       0.87      0.20      0.32       200
#                        Drug paraphernalia/Pipes       1.00      0.16      0.27        69
#                               Drugs/Weight loss       1.00      0.06      0.11        83
#                                    Data/Pirated       0.95      0.60      0.74       182
#                                  Drugs/Steroids       0.93      0.92      0.92       942
#                              Drugs/Prescription       0.54      0.81      0.65      1844
#                              Information/Guides       0.35      0.06      0.11       320
#                          Forgeries/Scans/Photos       0.98      0.51      0.67       109
#                                           Other       0.94      0.09      0.17       477
#                                         Jewelry       0.77      0.58      0.66       129
#                                     Drugs/Other       0.98      0.22      0.36       274
#                        Counterfeits/Accessories       0.80      0.34      0.48        71
#                            Counterfeits/Watches       0.97      0.97      0.97       352
#                             Drugs/Cannabis/Weed       0.54      1.00      0.70      6898
#                                    Drugs/Benzos       0.80      0.93      0.86      1750
#                       Drugs/Cannabis/Shake/trim       0.00      0.00      0.00        44
#                       Drugs/Cannabis/Synthetics       1.00      0.38      0.56       234
#                     Drugs/Cannabis/Concentrates       0.93      0.71      0.81      1429
#                            Drugs/Cannabis/Seeds       1.00      0.02      0.03       173
#                             Drugs/Cannabis/Hash       0.98      0.68      0.81      1058
#                         Drugs/Dissociatives/MXE       0.91      0.27      0.42       143
#                    Drugs/Dissociatives/Ketamine       1.00      0.47      0.64       339
#                          Drugs/Cannabis/Edibles       0.97      0.42      0.59       360
#                             Drugs/Ecstasy/Pills       0.83      0.98      0.90      2497
#                             Drugs/Ecstasy/Other       0.90      0.36      0.51       336
#                           Drugs/Stimulants/Meth       0.98      0.78      0.87       828
#                          Drugs/Psychedelics/LSD       0.93      0.96      0.95      1271
#                     Drug paraphernalia/Grinders       1.00      0.43      0.60        30
#                         Info/eBooks/Aliens/UFOs       0.00      0.00      0.00         4
#                        Drug paraphernalia/Paper       0.00      0.00      0.00        23
#                                 Services/Travel       0.00      0.00      0.00        33
#                    Drugs/Opioids/Dihydrocodeine       0.00      0.00      0.00        14
#                     Drugs/Stimulants/Mephedrone       0.00      0.00      0.00         9
#                         Drugs/Dissociatives/GBL       0.50      0.05      0.10        19
#                        Counterfeits/Electronics       0.00      0.00      0.00        15
# Drug paraphernalia/Injecting equipment/Syringes       0.00      0.00      0.00        12
#                             Drugs/Opioids/Opium       0.00      0.00      0.00        25
#    Drug paraphernalia/Injecting equipment/Other       0.00      0.00      0.00         9
#                       Drugs/Psychedelics/Salvia       0.00      0.00      0.00         9
#                              Drugs/Barbiturates       0.00      0.00      0.00        10
#                               Weapons/Fireworks       0.00      0.00      0.00         5
#                       Drug paraphernalia/Scales       0.00      0.00      0.00        12
#  Drug paraphernalia/Injecting equipment/Filters       0.00      0.00      0.00         2
#  Drug paraphernalia/Injecting equipment/Needles       0.00      0.00      0.00         5
#                         Drugs/Dissociatives/PCP       0.00      0.00      0.00         1
#
#                                        accuracy                           0.72     36164
#                                       macro avg       0.56      0.27      0.31     36164
#                                    weighted avg       0.77      0.72      0.68     36164
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### Logistic Regression

# %%
plot_confusion_matrix('Logistic Regression', y_predLogisticRegression)

# %%
print(metrics.classification_report(y_test, y_predLogisticRegression, target_names=df['Category'].unique()))
# Out:
#                                                  precision    recall  f1-score   support
#
#                                Services/Hacking       0.59      0.39      0.47       146
#                                  Services/Other       0.65      0.18      0.28       168
#                                       Drugs/RCs       0.76      0.87      0.81       703
#                    Forgeries/Physical documents       0.84      0.82      0.83       197
#                                  Tobacco/Smoked       0.99      0.87      0.93       131
#                                  Services/Money       0.53      0.79      0.63       448
#                              Counterfeits/Money       0.93      0.77      0.84       129
#                                   Data/Software       0.70      0.52      0.59       110
#                                   Data/Accounts       0.78      0.78      0.78       400
#                           Counterfeits/Clothing       0.90      0.79      0.84       134
#                              Information/eBooks       0.33      0.47      0.39       298
#                                     Electronics       0.72      0.65      0.68       200
#                        Drug paraphernalia/Pipes       0.85      0.51      0.64        69
#                               Drugs/Weight loss       0.89      0.37      0.53        83
#                                    Data/Pirated       0.93      0.76      0.84       182
#                                  Drugs/Steroids       0.92      0.95      0.94       942
#                              Drugs/Prescription       0.70      0.76      0.73      1844
#                              Information/Guides       0.36      0.40      0.38       320
#                          Forgeries/Scans/Photos       0.94      0.67      0.78       109
#                                           Other       0.48      0.38      0.42       477
#                                         Jewelry       0.74      0.71      0.73       129
#                                     Drugs/Other       0.95      0.34      0.50       274
#                        Counterfeits/Accessories       0.77      0.58      0.66        71
#                            Counterfeits/Watches       0.96      0.98      0.97       352
#                             Drugs/Cannabis/Weed       0.83      0.99      0.90      6898
#                                  Info/eBooks/IT       0.28      0.11      0.16        46
#                          Info/eBooks/Psychology       0.00      0.00      0.00        19
#                        Info/eBooks/Making money       0.57      0.15      0.24       114
#                     Weapons/Non-lethal firearms       0.80      0.62      0.70        13
#                           Tobacco/Paraphernalia       0.00      0.00      0.00        10
#                                 Forgeries/Other       0.88      0.58      0.70        26
#                              Weapons/Ammunition       0.94      0.75      0.83        40
#                                       Forgeries       0.00      0.00      0.00         3
#                                       Chemicals       1.00      0.50      0.67        30
#                       Drugs/Psychedelics/Spores       0.67      0.15      0.24        27
#                       Drugs/Opioids/Hydrocodone       0.78      0.61      0.69        57
#                          Info/eBooks/Philosophy       0.00      0.00      0.00         9
#                       Drugs/Dissociatives/Other       1.00      0.55      0.71        20
#                           Drugs/Opioids/Codeine       0.60      0.18      0.28        33
#                     Drug paraphernalia/Grinders       0.79      0.77      0.78        30
#                         Info/eBooks/Aliens/UFOs       0.00      0.00      0.00         4
#                        Drug paraphernalia/Paper       1.00      0.57      0.72        23
#                                 Services/Travel       0.55      0.91      0.68        33
#                    Drugs/Opioids/Dihydrocodeine       1.00      0.79      0.88        14
#                     Drugs/Stimulants/Mephedrone       1.00      0.11      0.20         9
#                         Drugs/Dissociatives/GBL       0.86      0.95      0.90        19
#                        Counterfeits/Electronics       0.00      0.00      0.00        15
# Drug paraphernalia/Injecting equipment/Syringes       0.88      0.58      0.70        12
#                             Drugs/Opioids/Opium       0.92      0.48      0.63        25
#    Drug paraphernalia/Injecting equipment/Other       0.00      0.00      0.00         9
#                       Drugs/Psychedelics/Salvia       1.00      0.89      0.94         9
#                              Drugs/Barbiturates       0.00      0.00      0.00        10
#                               Weapons/Fireworks       0.00      0.00      0.00         5
#                       Drug paraphernalia/Scales       0.55      0.50      0.52        12
#  Drug paraphernalia/Injecting equipment/Filters       0.00      0.00      0.00         2
#  Drug paraphernalia/Injecting equipment/Needles       0.00      0.00      0.00         5
#                         Drugs/Dissociatives/PCP       0.00      0.00      0.00         1
#
#                                        accuracy                           0.85     36164
#                                       macro avg       0.70      0.55      0.59     36164
#                                    weighted avg       0.85      0.85      0.84     36164
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### SGD Classifier

# %%
plot_confusion_matrix('SGD Classifier', y_predSGDClassifier)

# %%
print(metrics.classification_report(y_test, y_predSGDClassifier, target_names=df['Category'].unique()))
# Out:
#                                                  precision    recall  f1-score   support
#
#                                Services/Hacking       0.48      0.56      0.52       146
#                                  Services/Other       0.29      0.40      0.34       168
#                                       Drugs/RCs       0.90      0.89      0.89       703
#                    Forgeries/Physical documents       0.81      0.90      0.85       197
#                                  Tobacco/Smoked       0.94      0.94      0.94       131
#                                  Services/Money       0.68      0.73      0.70       448
#                              Counterfeits/Money       0.73      0.88      0.80       129
#                                   Data/Software       0.61      0.71      0.66       110
#                                   Data/Accounts       0.80      0.79      0.79       400
#                           Counterfeits/Clothing       0.90      0.90      0.90       134
#                          Drugs/Opioids/Morphine       0.64      0.87      0.73        89
#                             Drugs/Opioids/Other       0.53      0.64      0.58       209
#                            Drugs/Opioids/Heroin       0.87      0.91      0.89       564
#                             Info/eBooks/Science       0.25      0.35      0.29        55
#                                   Weapons/Melee       0.91      0.79      0.85        38
#                               Info/eBooks/Other       0.24      0.18      0.21       239
#                               Info/eBooks/Drugs       0.42      0.68      0.52        93
#                          Drugs/Opioids/Fentanyl       0.86      0.94      0.90       269
#                         Drugs/Opioids/Oxycodone       0.79      0.91      0.85       447
#                        Drugs/Psychedelics/5-MeO       0.97      0.98      0.98        64
#                     Drugs/Opioids/Buprenorphine       0.73      0.94      0.82       100
#                   Drug paraphernalia/Containers       0.67      0.69      0.68        64
#                        Drugs/Psychedelics/Other       0.74      0.83      0.78        94
#                            Info/eBooks/Doomsday       0.69      0.52      0.59        21
#                                  Info/eBooks/IT       0.34      0.50      0.41        46
#                          Info/eBooks/Psychology       0.00      0.00      0.00        19
#                        Info/eBooks/Making money       0.28      0.36      0.32       114
#                     Weapons/Non-lethal firearms       0.62      0.77      0.69        13
#                           Tobacco/Paraphernalia       0.33      0.10      0.15        10
#                                 Forgeries/Other       0.57      0.62      0.59        26
#                              Weapons/Ammunition       0.78      1.00      0.88        40
#                                       Forgeries       1.00      0.33      0.50         3
#                                       Chemicals       0.85      0.73      0.79        30
#                       Drugs/Psychedelics/Spores       0.88      0.81      0.85        27
#                       Drugs/Opioids/Hydrocodone       0.57      0.88      0.69        57
#                          Info/eBooks/Philosophy       0.00      0.00      0.00         9
#                       Drugs/Dissociatives/Other       1.00      0.85      0.92        20
#                           Drugs/Opioids/Codeine       0.64      0.82      0.72        33
#                     Drug paraphernalia/Grinders       0.85      0.93      0.89        30
#                         Info/eBooks/Aliens/UFOs       0.00      0.00      0.00         4
#                        Drug paraphernalia/Paper       1.00      0.74      0.85        23
#                                 Services/Travel       0.56      0.91      0.69        33
#                    Drugs/Opioids/Dihydrocodeine       0.85      0.79      0.81        14
#                     Drugs/Stimulants/Mephedrone       0.53      0.89      0.67         9
#                         Drugs/Dissociatives/GBL       0.77      0.89      0.83        19
#                        Counterfeits/Electronics       0.88      0.47      0.61        15
# Drug paraphernalia/Injecting equipment/Syringes       0.65      0.92      0.76        12
#                             Drugs/Opioids/Opium       0.54      0.60      0.57        25
#    Drug paraphernalia/Injecting equipment/Other       0.80      0.44      0.57         9
#                       Drugs/Psychedelics/Salvia       1.00      0.89      0.94         9
#                              Drugs/Barbiturates       0.29      0.70      0.41        10
#                               Weapons/Fireworks       0.00      0.00      0.00         5
#                       Drug paraphernalia/Scales       0.65      0.92      0.76        12
#  Drug paraphernalia/Injecting equipment/Filters       0.00      0.00      0.00         2
#  Drug paraphernalia/Injecting equipment/Needles       1.00      0.60      0.75         5
#                         Drugs/Dissociatives/PCP       0.50      1.00      0.67         1
#
#                                        accuracy                           0.88     36164
#                                       macro avg       0.69      0.72      0.70     36164
#                                    weighted avg       0.88      0.88      0.88     36164
